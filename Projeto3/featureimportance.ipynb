# %%
import pandas as pd
import numpy as np
data=pd.read_csv('featureimportance.csv',header=0,sep=',')
#data.columns = ['Decision Tree','Logistic Regression','RFE']

# %%
data
# Out:
#                     Decision Tree            Logistic Regression  \
# 0                        duration                      euribor3m
# 1                     nr.employed                       duration
# 2                   cons.conf.idx               poutcome_success
# 3                         contact                  cons.conf.idx
# 4                       euribor3m           education_illiterate
# 5                             age                 cons.price.idx
# 6                  cons.price.idx                      month_mar
# 7                        campaign                            age
# 8           education_high.school                    default_yes
# 9                 day_of_week_mon                housing_unknown
# 10                day_of_week_thu                   loan_unknown
# 11                   emp.var.rate                    job_student
# 12                day_of_week_tue                      month_dec
# ...
